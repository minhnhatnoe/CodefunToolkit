# %%
from src.api.helper.graph import make_graph

await make_graph("BDOG_16")
# Out:
# 2021-06-28 00:00:00
# e:\CodefunToolkit\src\api\helper\graph.py:55: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
